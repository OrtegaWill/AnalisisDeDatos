# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importamos las clases
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd

# %%
#Cadena de conexion

uri = 'mongodb+srv://Tester:Tester123@cluster0.44diofv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
#uri = 'mongodb+srv://Tester:Tester123@cluster0.44diofv.mongodb.net/sample_airbnb?retryWrites=true&w=majority&appName=Cluster0'
#Nueva instancia de cliente mongo
client = MongoClient(uri, server_api=ServerApi('1'))

try:
    #Comprobamos la conexion
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(f"Error connecting to MongoDB: {e}")
    client = None
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#Conecta con sample_airbnb
dbname = client['sample_airbnb']
collection_name = dbname['listingsAndReviews']
#realiza la consulta para extraer los datos
listingsAndReviews_cursor = collection_name.find({})
listingsAndReviews_df = pd.DataFrame(listingsAndReviews_cursor)

# %%
listingsAndReviews_df.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  A short distance from Honolulu's billion dolla...
# 3  Here exists a very cozy room for rent in a sha...
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...
#
#                                                space  \
# ...
